# %% [markdown]
# sparkSession initilozation

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Constructors").getOrCreate()

# %%
constructor_schema = "constructorId INT, constructorRef STRING, name STRING,nationality STRING ,url STRING "

# %%
constructor_DF = spark.read.schema(constructor_schema).json("/FileStore/tables/constructors-1.json")

# %% [markdown]
# Drop url column

# %%
constructor_dropcolDF = constructor_DF.drop(constructor_DF["url"])

# %% [markdown]
# rename columns and add ingstion_date

# %%
from pyspark.sql.functions import current_timestamp

# %%
constructor_finalDF = constructor_dropcolDF.withColumnRenamed("constructorId", "constructor_id")\
                                           .withColumnRenamed("construcorRef","constructor_ref")\
                                           .withColumn("ingestion_date" , current_timestamp())

# %%
constructor_finalDF.write.mode("overwrite").parquet("/FileStore/tables/output.45/constructorsoutput")

# %%
# %fs
ls /FileStore/tables/output.45/constructorsoutput
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/output.45/constructorsoutput/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/output.45/constructorsoutput/_committed_5917973547749582321</td><td>_committed_5917973547749582321</td><td>122</td></tr><tr><td>dbfs:/FileStore/tables/output.45/constructorsoutput/_started_5917973547749582321</td><td>_started_5917973547749582321</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/output.45/constructorsoutput/part-00000-tid-5917973547749582321-e94d3890-dffe-4bfb-9154-60758b1d14d6-5-1-c000.snappy.parquet</td><td>part-00000-tid-5917973547749582321-e94d3890-dffe-4bfb-9154-60758b1d14d6-5-1-c000.snappy.parquet</td><td>6490</td></tr></tbody></table></div>
